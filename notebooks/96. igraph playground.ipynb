# %%
# NOTE !pip install python-igraph cairocffi 
import igraph as ig
print('igraph version:', ig.__version__)
# Out:
# igraph version: 0.9.6

# %%
g = ig.Graph()

g.add_vertices(3)
g.add_edges([(0,1), (1,2)])
# g.vs[0]['name'] = 'test'
# g.vs[0].attributes()

# print(g)
ig.summary(g)

g =ig.Graph.GRG(10, .8)

ig.plot(g)
# Out:
# IGRAPH U--- 3 2 --

# %%
import random
random.seed(42)

g = ig.Graph.Erdos_Renyi(10,.8)
comms = g.community_multilevel()

ig.plot(comms, mark_groups = True)

# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns; sns.set_theme()  # noqa
from umap import UMAP
from python.cogtext.pubmed.preprocessing import PubMedPreprocessor

# %%
# Data and parameters
PUBMED = pd.read_csv('data/pubmed/abstracts.csv.gz').dropna(subset=['abstract']).reset_index()
PUBMED = PUBMED.sample(frac=0.5, weights='subcategory', random_state=0)

PUBMED = PUBMED.pipe(PubMedPreprocessor.select_relevant_journals)
PUBMED = PUBMED.pipe(PubMedPreprocessor.remove_short_abstracts)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3_/gmvd1nkx285133z5yh3chz2c0000gp/T/ipykernel_33628/2906603671.py in <module>
#       1 # Data and parameters
#       2 PUBMED = pd.read_csv('data/pubmed/abstracts.csv.gz').dropna(subset=['abstract']).reset_index()
# ----> 3 PUBMED = PUBMED.sample(frac=0.5, weights='subcategory', random_state=0)
#       4
#       5 PUBMED = PUBMED.pipe(PubMedPreprocessor.select_relevant_journals)
#
# /usr/local/Caskroom/miniforge/base/envs/py3/lib/python3.9/site-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5327                 raise ValueError("weight vector may not include `inf` values")
#    5328
# -> 5329             if (weights < 0).any():
#    5330                 raise ValueError("weight vector many not include negative values")
#    5331
#
# /usr/local/Caskroom/miniforge/base/envs/py3/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /usr/local/Caskroom/miniforge/base/envs/py3/lib/python3.9/site-packages/pandas/core/arraylike.py in __lt__(self, other)
#      38     @unpack_zerodim_and_defer("__lt__")
#      39     def __lt__(self, other):
# ---> 40         return self._cmp_method(other, operator.lt)
#      41
#      42     @unpack_zerodim_and_defer("__le__")
#
# /usr/local/Caskroom/miniforge/base/envs/py3/lib/python3.9/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    5500
#    5501         with np.errstate(all="ignore"):
# -> 5502             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5503
#    5504         return self._construct_result(res_values, name=res_name)
#
# /usr/local/Caskroom/miniforge/base/envs/py3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     282
#     283     elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 284         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285
#     286     else:
#
# /usr/local/Caskroom/miniforge/base/envs/py3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      71         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      72     else:
# ---> 73         result = libops.scalar_compare(x.ravel(), y, op)
#      74     return result.reshape(x.shape)
#      75
#
# /usr/local/Caskroom/miniforge/base/envs/py3/lib/python3.9/site-packages/pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
# pretrained document embeddings
embeddings_file = 'models/universal-sentence-encoder-v4/abstracts_embeddings.npz'
# embeddings_file = 'models/all-MiniLM-L6-v2/abstracts_embeddings.npz'
doc_embeddings = np.load(embeddings_file)['arr_0']
doc_embeddings = doc_embeddings[PUBMED.index]
doc_embeddings = pd.DataFrame(doc_embeddings, index=PUBMED.index)
doc_embeddings['label'] = PUBMED['subcategory']

embeddings = doc_embeddings.groupby('label').max()

# %%
fig, ax = plt.subplots(1,1, figsize=(10,10))

# embeddings_2d = PCA(n_components=2, random_state=0).fit_transform(embeddings)
embeddings_2d = UMAP(n_components=2, random_state=0).fit_transform(embeddings)
embeddings_2d = pd.DataFrame(embeddings_2d, index=embeddings.index)

sns.scatterplot(data=embeddings_2d, x=0, y=1, ax=ax, palette='Accent', s=200)

for (lbl, x, y) in embeddings_2d.itertuples():
  lbl = f'{lbl[:12]}...' if len(lbl)>10 else lbl
  ax.text(x+0.01, y-np.random.random()*.01, f'{lbl}', alpha=0.5, fontsize=10)

plt.suptitle('PCA projection of the topic embeddings.')
plt.show()
# Out:
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
from sklearn.metrics.pairwise import cosine_similarity
embeddings_sim = cosine_similarity(embeddings)
embeddings_sim = pd.DataFrame(embeddings_sim, index=embeddings.index, columns=embeddings.index)
sns.clustermap(embeddings_sim, figsize=(20,20))
plt.show()
# Out:
# /usr/local/Caskroom/miniforge/base/envs/py3/lib/python3.9/site-packages/seaborn/matrix.py:654: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
